# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
import torchvision.transforms as T
from torch.utils.data import DataLoader,Subset

import numpy as np
import matplotlib.pyplot as plt

from torchvision.utils import save_image
from torchvision.utils import make_grid
import sys
import os

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
imageAugment = T.Compose([
    T.Resize((64,64)),
    T.ToTensor(),
    T.Normalize([0.5,0.5,0.5],
                [0.5,0.5,0.5])])

# %%
batchsize = 200
stats = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)

# %%
dataPath = './data'

# %%
data =  DataLoader(torchvision.datasets.ImageFolder(dataPath,transform= imageAugment),batch_size=batchsize,shuffle=True)

# %%
class discriminatorNet(nn.Module):
  def __init__(self):
    super().__init__()

    # convolution layers
    self.conv1 = nn.Conv2d(  3, 64, 4, 2, 1, bias=False)
    self.conv2 = nn.Conv2d( 64,128, 4, 2, 1, bias=False)
    self.conv3 = nn.Conv2d(128,256, 4, 2, 1, bias=False)
    self.conv4 = nn.Conv2d(256,512, 4, 2, 1, bias=False)
    self.conv5 = nn.Conv2d(512,  1, 4, 1, 0, bias=False)

    # batchnorm
    self.bn2 = nn.BatchNorm2d(128)
    self.bn3 = nn.BatchNorm2d(256)
    self.bn4 = nn.BatchNorm2d(512)
    
  def forward(self,x):
    x = F.leaky_relu( self.conv1(x) ,.2)
    x = F.leaky_relu( self.conv2(x) ,.2)
    x = self.bn2(x)
    x = F.leaky_relu( self.conv3(x) ,.2)
    x = self.bn3(x)
    x = F.leaky_relu( self.conv4(x) ,.2)
    x = self.bn4(x)
    return torch.sigmoid(self.conv5(x)).view(-1,1)

# %%
class generatorNet(nn.Module):
  def __init__(self):
    super().__init__()

    # convolution layers
    self.conv1 = nn.ConvTranspose2d(200,512, 4, 1, 0, bias=False)
    self.conv2 = nn.ConvTranspose2d(512,256, 4, 2, 1, bias=False)
    self.conv3 = nn.ConvTranspose2d(256,128, 4, 2, 1, bias=False)
    self.conv4 = nn.ConvTranspose2d(128, 64, 4, 2, 1, bias=False)
    self.conv5 = nn.ConvTranspose2d(64,   3, 4, 2, 1, bias=False)

    # batchnorm
    self.bn1 = nn.BatchNorm2d(512)
    self.bn2 = nn.BatchNorm2d(256)
    self.bn3 = nn.BatchNorm2d(128)
    self.bn4 = nn.BatchNorm2d( 64)


  def forward(self,x):
    x = F.relu( self.bn1(self.conv1(x)) )
    x = F.relu( self.bn2(self.conv2(x)) )
    x = F.relu( self.bn3(self.conv3(x)) )
    x = F.relu( self.bn4(self.conv4(x)) )
    x = torch.tanh( self.conv5(x) )
    return x

# %%
discriminator = discriminatorNet().to(device=device)
generator = generatorNet().to(device=device)

# %%
optimizer_d = torch.optim.Adam(discriminator.parameters(),lr=0.001)
optimizer_g = torch.optim.Adam(generator.parameters(),lr = 0.001)

# %%
def trainDISCRIMINATOR(realImages,optimizer):
    optimizer.zero_grad()

    #discriminator with real images
    
    yHat_real = discriminator(realImages.to(device)).to(device)
    real_labels = torch.ones(realImages.size(0),1,device=device)
    #print(yHat_real.size())
    real_loss = F.binary_cross_entropy(yHat_real,real_labels)
   


    #generating fake data

    imageParameter = torch.randn(batchsize, 200, 1, 1)
    fake_images = generator(imageParameter.to(device))

    #discriminator with fake images

    fake_labels = torch.zeros(fake_images.size(0), 1, device=device)
    yHat_fake = discriminator(fake_images.to(device))
    fake_loss = F.binary_cross_entropy(yHat_fake,fake_labels)


    loss = real_loss + fake_loss
    loss.backward()
    optimizer.step()
    return loss.item()

# %%
def trainGenerator(optimizer):
    optimizer.zero_grad()

    #generating fake images
    imageParameter = torch.randn(batchsize, 200, 1, 1)
    fakeImages = generator(imageParameter.to(device))

    #fooling discriminator
    prediction = discriminator(fakeImages.to(device))
    labels = torch.ones(200,1,device=device)
    loss = F.binary_cross_entropy(prediction,labels)

    loss.backward()
    optimizer.step()

    return loss.item()

# %%
def denorm(img_tensors):
    return img_tensors * stats[1][0] + stats[0][0]

# %%
sample_dir = 'generated'
os.makedirs(sample_dir, exist_ok=True)

# %%
def save_samples(index, latent_tensors, show=True):
    fake_images = generator(latent_tensors)
    fake_fname = 'generated-images-{0:0=4d}.png'.format(index)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=8)
    print('Saving', fake_fname)
    if show:
        fig, ax = plt.subplots(figsize=(8, 8))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(fake_images.cpu().detach(), nrow=8).permute(1, 2, 0))

# %%
def trainModel(epochs):

    generator_Losses = []
    discriminator_Losses = []
    
    for epoch in range(epochs):
        for realImages, _ in  data:
            
            lossD = trainDISCRIMINATOR(realImages,optimizer_d)

            lossG = trainGenerator(optimizer_g)

        generator_Losses.append(lossG)
        discriminator_Losses.append(lossD)

        print("Epoch [{}/{}], loss_g: {:.4f}, loss_d: {:.4f}".format(
        epoch+1, epochs, lossG, lossD))

        fixed_latent = torch.randn(64, 200, 1, 1, device=device)

        save_samples(epoch+1,fixed_latent,show=False)

    return generator_Losses,discriminator_Losses

# %%
epochs = 2000

# %%
history = trainModel(epochs)
# Out:
# Epoch [1/2000], loss_g: 10.9178, loss_d: 0.0188
# Saving generated-images-0001.png
# Epoch [2/2000], loss_g: 8.5219, loss_d: 0.0510
# Saving generated-images-0002.png
# Epoch [3/2000], loss_g: 13.1953, loss_d: 0.0687
# Saving generated-images-0003.png
# Epoch [4/2000], loss_g: 10.3835, loss_d: 0.0530
# Saving generated-images-0004.png
# Epoch [5/2000], loss_g: 11.8330, loss_d: 0.0143
# Saving generated-images-0005.png
# Epoch [6/2000], loss_g: 16.4586, loss_d: 0.0582
# Saving generated-images-0006.png
# Epoch [7/2000], loss_g: 11.8064, loss_d: 0.0099
# Saving generated-images-0007.png
# Epoch [8/2000], loss_g: 7.7453, loss_d: 0.0341
# Saving generated-images-0008.png
# Epoch [9/2000], loss_g: 11.2003, loss_d: 0.0292
# Saving generated-images-0009.png
# Epoch [10/2000], loss_g: 14.0679, loss_d: 0.0785
# Saving generated-images-0010.png
# Epoch [11/2000], loss_g: 11.7605, loss_d: 0.0199
# Saving generated-images-0011.png
# Epoch [12/2000], loss_g: 12.3835, loss_d: 0.0213
# Saving generated-images-0012.png
# Epoch [13/2000], loss_g: 13.6005, loss_d: 0.0171
# Saving generated-images-0013.png
# Epoch [14/2000], loss_g: 9.7208, loss_d: 0.0009
# Saving generated-images-0014.png
# Epoch [15/2000], loss_g: 12.5324, loss_d: 0.0154
# Saving generated-images-0015.png
# Epoch [16/2000], loss_g: 17.6908, loss_d: 0.0087
# Saving generated-images-0016.png
# Epoch [17/2000], loss_g: 10.6118, loss_d: 0.0588
# Saving generated-images-0017.png
# Epoch [18/2000], loss_g: 12.2324, loss_d: 0.0292
# Saving generated-images-0018.png
# Epoch [19/2000], loss_g: 12.9342, loss_d: 0.0194
# Saving generated-images-0019.png
# Epoch [20/2000], loss_g: 20.5167, loss_d: 0.1984
# Saving generated-images-0020.png
# Epoch [21/2000], loss_g: 15.7403, loss_d: 0.0110
# Saving generated-images-0021.png
# Epoch [22/2000], loss_g: 8.2410, loss_d: 0.0084
# Saving generated-images-0022.png
# Epoch [23/2000], loss_g: 16.2861, loss_d: 0.0452
# Saving generated-images-0023.png
# Epoch [24/2000], loss_g: 15.7263, loss_d: 0.1113
# Saving generated-images-0024.png
# Epoch [25/2000], loss_g: 12.5978, loss_d: 0.0190
# Saving generated-images-0025.png
# Epoch [26/2000], loss_g: 12.6135, loss_d: 0.0140
# Saving generated-images-0026.png
# Epoch [27/2000], loss_g: 16.7452, loss_d: 0.0750
# Saving generated-images-0027.png
# Epoch [28/2000], loss_g: 26.2222, loss_d: 0.0061
# Saving generated-images-0028.png
# Epoch [29/2000], loss_g: 13.9403, loss_d: 0.0470
# Saving generated-images-0029.png
# Epoch [30/2000], loss_g: 15.1677, loss_d: 0.0034
# Saving generated-images-0030.png
# Epoch [31/2000], loss_g: 17.2519, loss_d: 0.0030
# Saving generated-images-0031.png
# Epoch [32/2000], loss_g: 24.5060, loss_d: 0.2418
# Saving generated-images-0032.png
# Epoch [33/2000], loss_g: 22.6892, loss_d: 0.0552
# Saving generated-images-0033.png
# Epoch [34/2000], loss_g: 9.1493, loss_d: 0.0620
# Saving generated-images-0034.png
# Epoch [35/2000], loss_g: 12.1897, loss_d: 0.0269
# Saving generated-images-0035.png
# Epoch [36/2000], loss_g: 22.4635, loss_d: 0.0375
# Saving generated-images-0036.png
# Epoch [37/2000], loss_g: 20.2204, loss_d: 0.0090
# Saving generated-images-0037.png
# Epoch [38/2000], loss_g: 47.2732, loss_d: 0.0000
# Saving generated-images-0038.png
# Epoch [39/2000], loss_g: 21.3446, loss_d: 0.0016
# Saving generated-images-0039.png
# Epoch [40/2000], loss_g: 21.4055, loss_d: 0.0084
# Saving generated-images-0040.png
# Epoch [41/2000], loss_g: 24.6914, loss_d: 0.0315
# Saving generated-images-0041.png
# Epoch [42/2000], loss_g: 50.1375, loss_d: 0.0000
# Saving generated-images-0042.png
# Epoch [43/2000], loss_g: 48.3779, loss_d: 0.0000
# Saving generated-images-0043.png
# Epoch [44/2000], loss_g: 23.6584, loss_d: 0.1649
# Saving generated-images-0044.png
# Epoch [45/2000], loss_g: 21.8656, loss_d: 0.0244
# Saving generated-images-0045.png
# Epoch [46/2000], loss_g: 15.9463, loss_d: 0.0608
# Saving generated-images-0046.png
# Epoch [47/2000], loss_g: 17.4709, loss_d: 0.0198
# Saving generated-images-0047.png
# Epoch [48/2000], loss_g: 14.7395, loss_d: 0.0179
# Saving generated-images-0048.png
# Epoch [49/2000], loss_g: 15.7103, loss_d: 0.0404
# Saving generated-images-0049.png
# Epoch [50/2000], loss_g: 26.5086, loss_d: 0.1314
# Saving generated-images-0050.png
# Epoch [51/2000], loss_g: 17.8132, loss_d: 0.0071
# Saving generated-images-0051.png
# Epoch [52/2000], loss_g: 22.9200, loss_d: 0.0002
# Saving generated-images-0052.png
# Epoch [53/2000], loss_g: 26.8908, loss_d: 0.0003
# Saving generated-images-0053.png
# Epoch [54/2000], loss_g: 17.3244, loss_d: 0.0474
# Saving generated-images-0054.png
# Epoch [55/2000], loss_g: 29.7830, loss_d: 0.0000
# Saving generated-images-0055.png
# Epoch [56/2000], loss_g: 33.2991, loss_d: 0.0001
# Saving generated-images-0056.png
# Epoch [57/2000], loss_g: 25.7325, loss_d: 0.0028
# Saving generated-images-0057.png
# Epoch [58/2000], loss_g: 14.2439, loss_d: 0.0059
# Saving generated-images-0058.png
# Epoch [59/2000], loss_g: 17.9068, loss_d: 0.1420
# Saving generated-images-0059.png
# Epoch [60/2000], loss_g: 24.8570, loss_d: 0.0003
# Saving generated-images-0060.png
# Epoch [61/2000], loss_g: 18.2218, loss_d: 0.0450
# Saving generated-images-0061.png
# Epoch [62/2000], loss_g: 20.9434, loss_d: 0.0114
# Saving generated-images-0062.png
# Epoch [63/2000], loss_g: 15.6715, loss_d: 0.0192
# Saving generated-images-0063.png
# Epoch [64/2000], loss_g: 21.1318, loss_d: 0.1629
# Saving generated-images-0064.png
# Epoch [65/2000], loss_g: 20.8250, loss_d: 0.0471
# Saving generated-images-0065.png
# Epoch [66/2000], loss_g: 24.1079, loss_d: 0.0081
# Saving generated-images-0066.png
# Epoch [67/2000], loss_g: 17.5184, loss_d: 0.0124
# Saving generated-images-0067.png
# Epoch [68/2000], loss_g: 32.1435, loss_d: 0.0000
# Saving generated-images-0068.png
# Epoch [69/2000], loss_g: 22.5690, loss_d: 0.0077
# Saving generated-images-0069.png
# Epoch [70/2000], loss_g: 36.0642, loss_d: 0.0380
# Saving generated-images-0070.png
# Epoch [71/2000], loss_g: 50.5102, loss_d: 0.0000
# Saving generated-images-0071.png
# Epoch [72/2000], loss_g: 22.9280, loss_d: 0.0006
# Saving generated-images-0072.png
# Epoch [73/2000], loss_g: 27.0453, loss_d: 0.0224
# Saving generated-images-0073.png
# Epoch [74/2000], loss_g: 24.6451, loss_d: 0.1544
# Saving generated-images-0074.png
# Epoch [75/2000], loss_g: 18.6630, loss_d: 0.0023
# Saving generated-images-0075.png
# Epoch [76/2000], loss_g: 33.2800, loss_d: 0.0000
# Saving generated-images-0076.png
# Epoch [77/2000], loss_g: 13.4579, loss_d: 0.0024
# Saving generated-images-0077.png
# Epoch [78/2000], loss_g: 14.7073, loss_d: 0.1402
# Saving generated-images-0078.png
# Epoch [79/2000], loss_g: 20.5540, loss_d: 0.0841
# Saving generated-images-0079.png
# Epoch [80/2000], loss_g: 11.2070, loss_d: 0.0998
# Saving generated-images-0080.png
# Epoch [81/2000], loss_g: 16.9709, loss_d: 0.0765
# Saving generated-images-0081.png
# Epoch [82/2000], loss_g: 14.3754, loss_d: 0.0892
# Saving generated-images-0082.png
# Epoch [83/2000], loss_g: 19.2367, loss_d: 0.1019
# Saving generated-images-0083.png
# Epoch [84/2000], loss_g: 14.5045, loss_d: 0.0623
# Saving generated-images-0084.png
# Epoch [85/2000], loss_g: 13.4218, loss_d: 0.0058
# Saving generated-images-0085.png
# Epoch [86/2000], loss_g: 11.9062, loss_d: 0.0525
# Saving generated-images-0086.png
# Epoch [87/2000], loss_g: 10.1003, loss_d: 0.0027
# Saving generated-images-0087.png
# Epoch [88/2000], loss_g: 17.1785, loss_d: 0.0095
# Saving generated-images-0088.png
# Epoch [89/2000], loss_g: 11.2606, loss_d: 0.0045
# Saving generated-images-0089.png
# Epoch [90/2000], loss_g: 11.8799, loss_d: 0.0005
# Saving generated-images-0090.png
# Epoch [91/2000], loss_g: 17.5734, loss_d: 0.0508
# Saving generated-images-0091.png
# Epoch [92/2000], loss_g: 15.1689, loss_d: 0.0144
# Saving generated-images-0092.png
# Epoch [93/2000], loss_g: 17.3204, loss_d: 0.0380
# Saving generated-images-0093.png
# Epoch [94/2000], loss_g: 19.3898, loss_d: 0.0092
# Saving generated-images-0094.png
# Epoch [95/2000], loss_g: 13.5943, loss_d: 0.0128
# Saving generated-images-0095.png
# Epoch [96/2000], loss_g: 17.7011, loss_d: 0.0091
# Saving generated-images-0096.png
# Epoch [97/2000], loss_g: 12.1559, loss_d: 0.0003
# Saving generated-images-0097.png
# Epoch [98/2000], loss_g: 18.4299, loss_d: 0.0156
# Saving generated-images-0098.png
# Epoch [99/2000], loss_g: 15.5482, loss_d: 0.0797
# Saving generated-images-0099.png
# Epoch [100/2000], loss_g: 36.0836, loss_d: 0.0000
# Saving generated-images-0100.png
# Epoch [101/2000], loss_g: 13.5220, loss_d: 0.1220
# Saving generated-images-0101.png
# Epoch [102/2000], loss_g: 29.5345, loss_d: 0.0000
# Saving generated-images-0102.png
# Epoch [103/2000], loss_g: 19.7697, loss_d: 0.1733
# Saving generated-images-0103.png
# Epoch [104/2000], loss_g: 16.4264, loss_d: 0.0943
# Saving generated-images-0104.png
# Epoch [105/2000], loss_g: 13.6666, loss_d: 0.0751
# Saving generated-images-0105.png
# Epoch [106/2000], loss_g: 25.4344, loss_d: 0.0000
# Saving generated-images-0106.png
# Epoch [107/2000], loss_g: 14.1596, loss_d: 0.0821
# Saving generated-images-0107.png
# Epoch [108/2000], loss_g: 15.7499, loss_d: 0.1319
# Saving generated-images-0108.png
# Epoch [109/2000], loss_g: 13.0490, loss_d: 0.0390
# Saving generated-images-0109.png
# Epoch [110/2000], loss_g: 12.6810, loss_d: 0.0344
# Saving generated-images-0110.png
# Epoch [111/2000], loss_g: 13.1072, loss_d: 0.0498
# Saving generated-images-0111.png
# Epoch [112/2000], loss_g: 15.1329, loss_d: 0.0015
# Saving generated-images-0112.png
# Epoch [113/2000], loss_g: 11.5189, loss_d: 0.0859
# Saving generated-images-0113.png
# Epoch [114/2000], loss_g: 16.0172, loss_d: 0.0296
# Saving generated-images-0114.png
# Epoch [115/2000], loss_g: 11.7578, loss_d: 0.0098
# Saving generated-images-0115.png
# Epoch [116/2000], loss_g: 16.1113, loss_d: 0.0037
# Saving generated-images-0116.png
# Epoch [117/2000], loss_g: 9.3359, loss_d: 0.0176
# Saving generated-images-0117.png
# Epoch [118/2000], loss_g: 8.8541, loss_d: 0.0349
# Saving generated-images-0118.png
# Epoch [119/2000], loss_g: 7.5188, loss_d: 0.0053
# Saving generated-images-0119.png
# Epoch [120/2000], loss_g: 14.7691, loss_d: 0.0077
# Saving generated-images-0120.png
# Epoch [121/2000], loss_g: 12.3624, loss_d: 0.2769
# Saving generated-images-0121.png
# Epoch [122/2000], loss_g: 31.3575, loss_d: 0.0000
# Saving generated-images-0122.png
# Epoch [123/2000], loss_g: 13.5000, loss_d: 0.0249
# Saving generated-images-0123.png
# Epoch [124/2000], loss_g: 7.3309, loss_d: 0.0013
# Saving generated-images-0124.png
# Epoch [125/2000], loss_g: 46.7695, loss_d: 0.0000
# Saving generated-images-0125.png
# Epoch [126/2000], loss_g: 11.3003, loss_d: 0.0135
# Saving generated-images-0126.png
# Epoch [127/2000], loss_g: 63.3022, loss_d: 0.0000
# Saving generated-images-0127.png
# Epoch [128/2000], loss_g: 63.5302, loss_d: 0.0000
# Saving generated-images-0128.png
# Epoch [129/2000], loss_g: 63.1337, loss_d: 0.0000
# Saving generated-images-0129.png
# Epoch [130/2000], loss_g: 63.7309, loss_d: 0.0000
# Saving generated-images-0130.png
# Epoch [131/2000], loss_g: 63.4749, loss_d: 0.0000
# Saving generated-images-0131.png
# Epoch [132/2000], loss_g: 63.1649, loss_d: 0.0000
# Saving generated-images-0132.png
# Epoch [133/2000], loss_g: 62.8866, loss_d: 0.0000
# Saving generated-images-0133.png
# Epoch [134/2000], loss_g: 62.6464, loss_d: 0.0000
# Saving generated-images-0134.png
# Epoch [135/2000], loss_g: 61.8891, loss_d: 0.0000
# Saving generated-images-0135.png
# Epoch [136/2000], loss_g: 63.8653, loss_d: 0.0000
# Saving generated-images-0136.png
# Epoch [137/2000], loss_g: 62.5416, loss_d: 0.0000
# Saving generated-images-0137.png
# Epoch [138/2000], loss_g: 62.5383, loss_d: 0.0000
# Saving generated-images-0138.png
# Epoch [139/2000], loss_g: 64.6120, loss_d: 0.0000
# Saving generated-images-0139.png
# Epoch [140/2000], loss_g: 63.3404, loss_d: 0.0000
# Saving generated-images-0140.png
# Epoch [141/2000], loss_g: 63.8988, loss_d: 0.0000
# Saving generated-images-0141.png
# Epoch [142/2000], loss_g: 64.4041, loss_d: 0.0000
# Saving generated-images-0142.png
# Epoch [143/2000], loss_g: 61.9719, loss_d: 0.0000
# Saving generated-images-0143.png
# Epoch [144/2000], loss_g: 61.3704, loss_d: 0.0000
# Saving generated-images-0144.png
# Epoch [145/2000], loss_g: 63.2838, loss_d: 0.0000
# Saving generated-images-0145.png
# Epoch [146/2000], loss_g: 62.2176, loss_d: 0.0000
# Saving generated-images-0146.png
# Epoch [147/2000], loss_g: 61.5112, loss_d: 0.0000
# Saving generated-images-0147.png
# Epoch [148/2000], loss_g: 62.7962, loss_d: 0.0000
# Saving generated-images-0148.png
# Epoch [149/2000], loss_g: 63.9896, loss_d: 0.0000
# Saving generated-images-0149.png
# Epoch [150/2000], loss_g: 61.4395, loss_d: 0.0000
# Saving generated-images-0150.png
# Epoch [151/2000], loss_g: 61.8694, loss_d: 0.0000
# Saving generated-images-0151.png
# Epoch [152/2000], loss_g: 62.6768, loss_d: 0.0000
# Saving generated-images-0152.png
# Epoch [153/2000], loss_g: 61.4337, loss_d: 0.0000
# Saving generated-images-0153.png
# Epoch [154/2000], loss_g: 61.7051, loss_d: 0.0000
# Saving generated-images-0154.png
# Epoch [155/2000], loss_g: 61.3131, loss_d: 0.0000
# Saving generated-images-0155.png
# Epoch [156/2000], loss_g: 61.0465, loss_d: 0.0000
# Saving generated-images-0156.png
# Epoch [157/2000], loss_g: 60.6517, loss_d: 0.0000
# Saving generated-images-0157.png
# Epoch [158/2000], loss_g: 61.4084, loss_d: 0.0000
# Saving generated-images-0158.png
# Epoch [159/2000], loss_g: 7.3113, loss_d: 0.0005
# Saving generated-images-0159.png
# Epoch [160/2000], loss_g: 48.0617, loss_d: 0.0000
# Saving generated-images-0160.png
# Epoch [161/2000], loss_g: 28.1127, loss_d: 0.0532
# Saving generated-images-0161.png
# Epoch [162/2000], loss_g: 18.6907, loss_d: 0.1149
# Saving generated-images-0162.png
# Epoch [163/2000], loss_g: 21.2917, loss_d: 0.0759
# Saving generated-images-0163.png
# Epoch [164/2000], loss_g: 21.2460, loss_d: 0.0300
# Saving generated-images-0164.png
# Epoch [165/2000], loss_g: 13.8514, loss_d: 0.0133
# Saving generated-images-0165.png
# Epoch [166/2000], loss_g: 66.1075, loss_d: 0.0000
# Saving generated-images-0166.png
# Epoch [167/2000], loss_g: 50.0152, loss_d: 0.0000
# Saving generated-images-0167.png
# Epoch [168/2000], loss_g: 20.8792, loss_d: 0.1076
# Saving generated-images-0168.png
# Epoch [169/2000], loss_g: 74.6326, loss_d: 0.0000
# Saving generated-images-0169.png
# Epoch [170/2000], loss_g: 72.4692, loss_d: 0.0000
# Saving generated-images-0170.png
# Epoch [171/2000], loss_g: 70.4672, loss_d: 0.0000
# Saving generated-images-0171.png
# Epoch [172/2000], loss_g: 71.6700, loss_d: 0.0000
# Saving generated-images-0172.png
# Epoch [173/2000], loss_g: 72.5067, loss_d: 0.0000
# Saving generated-images-0173.png
# Epoch [174/2000], loss_g: 74.0974, loss_d: 0.0000
# Saving generated-images-0174.png
# Epoch [175/2000], loss_g: 70.9340, loss_d: 0.0000
# Saving generated-images-0175.png
# Epoch [176/2000], loss_g: 71.4180, loss_d: 0.0000
# Saving generated-images-0176.png
# Epoch [177/2000], loss_g: 71.0782, loss_d: 0.0000
# Saving generated-images-0177.png
# Epoch [178/2000], loss_g: 74.8439, loss_d: 0.0000
# Saving generated-images-0178.png
# Epoch [179/2000], loss_g: 69.6855, loss_d: 0.0000
# Saving generated-images-0179.png
# Epoch [180/2000], loss_g: 70.4943, loss_d: 0.0000
# Saving generated-images-0180.png
# Epoch [181/2000], loss_g: 73.9349, loss_d: 0.0000
# Saving generated-images-0181.png
# Epoch [182/2000], loss_g: 71.4924, loss_d: 0.0000
# Saving generated-images-0182.png
# Epoch [183/2000], loss_g: 72.0519, loss_d: 0.0000
# Saving generated-images-0183.png
# Epoch [184/2000], loss_g: 71.4628, loss_d: 0.0000
# Saving generated-images-0184.png
# Epoch [185/2000], loss_g: 72.1619, loss_d: 0.0000
# Saving generated-images-0185.png
# Epoch [186/2000], loss_g: 71.9879, loss_d: 0.0000
# Saving generated-images-0186.png
# Epoch [187/2000], loss_g: 72.3502, loss_d: 0.0000
# Saving generated-images-0187.png
# Epoch [188/2000], loss_g: 74.6434, loss_d: 0.0000
# Saving generated-images-0188.png
# Epoch [189/2000], loss_g: 74.5724, loss_d: 0.0000
# Saving generated-images-0189.png
# Epoch [190/2000], loss_g: 73.3226, loss_d: 0.0000
# Saving generated-images-0190.png
# Epoch [191/2000], loss_g: 72.3693, loss_d: 0.0000
# Saving generated-images-0191.png
# Epoch [192/2000], loss_g: 71.9935, loss_d: 0.0000
# Saving generated-images-0192.png
# Epoch [193/2000], loss_g: 73.9031, loss_d: 0.0000
# Saving generated-images-0193.png
# Epoch [194/2000], loss_g: 71.8849, loss_d: 0.0000
# Saving generated-images-0194.png
# Epoch [195/2000], loss_g: 71.0717, loss_d: 0.0000
# Saving generated-images-0195.png
# Epoch [196/2000], loss_g: 71.2557, loss_d: 0.0000
# Saving generated-images-0196.png
# Epoch [197/2000], loss_g: 69.7613, loss_d: 0.0000
# Saving generated-images-0197.png
# Epoch [198/2000], loss_g: 69.5635, loss_d: 0.0000
# Saving generated-images-0198.png
# Epoch [199/2000], loss_g: 72.5153, loss_d: 0.0000
# Saving generated-images-0199.png
# Epoch [200/2000], loss_g: 71.2139, loss_d: 0.0000
# Saving generated-images-0200.png
# Epoch [201/2000], loss_g: 71.2704, loss_d: 0.0000
# Saving generated-images-0201.png
# Epoch [202/2000], loss_g: 73.3378, loss_d: 0.0000
# Saving generated-images-0202.png
# Epoch [203/2000], loss_g: 71.0677, loss_d: 0.0000
# Saving generated-images-0203.png
# Epoch [204/2000], loss_g: 73.7601, loss_d: 0.0000
# Saving generated-images-0204.png
# Epoch [205/2000], loss_g: 74.8033, loss_d: 0.0000
# Saving generated-images-0205.png
# Epoch [206/2000], loss_g: 73.7281, loss_d: 0.0000
# Saving generated-images-0206.png
# Epoch [207/2000], loss_g: 72.5791, loss_d: 0.0000
# Saving generated-images-0207.png
# Epoch [208/2000], loss_g: 70.0412, loss_d: 0.0000
# Saving generated-images-0208.png
# Epoch [209/2000], loss_g: 69.1276, loss_d: 0.0000
# Saving generated-images-0209.png
# Epoch [210/2000], loss_g: 70.0958, loss_d: 0.0000
# Saving generated-images-0210.png
# Epoch [211/2000], loss_g: 71.0416, loss_d: 0.0000
# Saving generated-images-0211.png
# Epoch [212/2000], loss_g: 71.7480, loss_d: 0.0000
# Saving generated-images-0212.png
# Epoch [213/2000], loss_g: 70.1540, loss_d: 0.0000
# Saving generated-images-0213.png
# Epoch [214/2000], loss_g: 70.7506, loss_d: 0.0000
# Saving generated-images-0214.png
# Epoch [215/2000], loss_g: 71.2390, loss_d: 0.0000
# Saving generated-images-0215.png
# Epoch [216/2000], loss_g: 68.4469, loss_d: 0.0000
# Saving generated-images-0216.png
# Epoch [217/2000], loss_g: 72.2372, loss_d: 0.0000
# Saving generated-images-0217.png
# Epoch [218/2000], loss_g: 72.3802, loss_d: 0.0000
# Saving generated-images-0218.png
# Epoch [219/2000], loss_g: 71.7395, loss_d: 0.0000
# Saving generated-images-0219.png
# Epoch [220/2000], loss_g: 70.7529, loss_d: 0.0000
# Saving generated-images-0220.png
# Epoch [221/2000], loss_g: 67.1214, loss_d: 0.0000
# Saving generated-images-0221.png
# Epoch [222/2000], loss_g: 70.4012, loss_d: 0.0000
# Saving generated-images-0222.png
# Epoch [223/2000], loss_g: 71.9449, loss_d: 0.0000
# Saving generated-images-0223.png
# Epoch [224/2000], loss_g: 69.5075, loss_d: 0.0000
# Saving generated-images-0224.png
# Epoch [225/2000], loss_g: 73.4668, loss_d: 0.0000
# Saving generated-images-0225.png
# Epoch [226/2000], loss_g: 71.3359, loss_d: 0.0000
# Saving generated-images-0226.png
# Epoch [227/2000], loss_g: 72.0186, loss_d: 0.0000
# Saving generated-images-0227.png
# Epoch [228/2000], loss_g: 71.8505, loss_d: 0.0000
# Saving generated-images-0228.png
# Epoch [229/2000], loss_g: 71.4461, loss_d: 0.0000
# Saving generated-images-0229.png
# Epoch [230/2000], loss_g: 67.9287, loss_d: 0.0000
# Saving generated-images-0230.png
# Epoch [231/2000], loss_g: 71.5524, loss_d: 0.0000
# Saving generated-images-0231.png
# Epoch [232/2000], loss_g: 72.3055, loss_d: 0.0000
# Saving generated-images-0232.png
# Epoch [233/2000], loss_g: 71.6360, loss_d: 0.0000
# Saving generated-images-0233.png
# Epoch [234/2000], loss_g: 69.1527, loss_d: 0.0000
# Saving generated-images-0234.png
# Epoch [235/2000], loss_g: 70.1501, loss_d: 0.0000
# Saving generated-images-0235.png
# Epoch [236/2000], loss_g: 71.0381, loss_d: 0.0000
# Saving generated-images-0236.png
# Epoch [237/2000], loss_g: 72.8953, loss_d: 0.0000
# Saving generated-images-0237.png
# Epoch [238/2000], loss_g: 70.1238, loss_d: 0.0000
# Saving generated-images-0238.png
# Epoch [239/2000], loss_g: 70.6551, loss_d: 0.0000
# Saving generated-images-0239.png
# Epoch [240/2000], loss_g: 71.0435, loss_d: 0.0000
# Saving generated-images-0240.png
# Epoch [241/2000], loss_g: 67.9889, loss_d: 0.0000
# Saving generated-images-0241.png
# Epoch [242/2000], loss_g: 71.7624, loss_d: 0.0000
# Saving generated-images-0242.png
# Epoch [243/2000], loss_g: 67.1972, loss_d: 0.0000
# Saving generated-images-0243.png
# Epoch [244/2000], loss_g: 71.5735, loss_d: 0.0000
# Saving generated-images-0244.png
# Epoch [245/2000], loss_g: 69.9289, loss_d: 0.0000
# Saving generated-images-0245.png
# Epoch [246/2000], loss_g: 71.8703, loss_d: 0.0000
# Saving generated-images-0246.png
# Epoch [247/2000], loss_g: 69.8125, loss_d: 0.0000
# Saving generated-images-0247.png
# Epoch [248/2000], loss_g: 71.1976, loss_d: 0.0000
# Saving generated-images-0248.png
# Epoch [249/2000], loss_g: 69.5019, loss_d: 0.0000
# Saving generated-images-0249.png
# Epoch [250/2000], loss_g: 70.2056, loss_d: 0.0000
# Saving generated-images-0250.png
# Epoch [251/2000], loss_g: 71.7270, loss_d: 0.0000
# Saving generated-images-0251.png
# Epoch [252/2000], loss_g: 68.9280, loss_d: 0.0000
# Saving generated-images-0252.png
# Epoch [253/2000], loss_g: 70.5389, loss_d: 0.0000
# Saving generated-images-0253.png
# Epoch [254/2000], loss_g: 71.5470, loss_d: 0.0000
# Saving generated-images-0254.png
# Epoch [255/2000], loss_g: 69.5697, loss_d: 0.0000
# Saving generated-images-0255.png
# Epoch [256/2000], loss_g: 68.5876, loss_d: 0.0000
# Saving generated-images-0256.png
# Epoch [257/2000], loss_g: 68.8269, loss_d: 0.0000
# Saving generated-images-0257.png
# Epoch [258/2000], loss_g: 69.7187, loss_d: 0.0000
# Saving generated-images-0258.png
# Epoch [259/2000], loss_g: 71.1547, loss_d: 0.0000
# Saving generated-images-0259.png
# Epoch [260/2000], loss_g: 69.1269, loss_d: 0.0000
# Saving generated-images-0260.png
# Epoch [261/2000], loss_g: 69.3690, loss_d: 0.0000
# Saving generated-images-0261.png
# Epoch [262/2000], loss_g: 70.7820, loss_d: 0.0000
# Saving generated-images-0262.png
# Epoch [263/2000], loss_g: 67.5249, loss_d: 0.0000
# Saving generated-images-0263.png
# Epoch [264/2000], loss_g: 66.6286, loss_d: 0.0000
# Saving generated-images-0264.png
# Epoch [265/2000], loss_g: 69.5016, loss_d: 0.0000
# Saving generated-images-0265.png
# Epoch [266/2000], loss_g: 70.1189, loss_d: 0.0000
# Saving generated-images-0266.png
# Epoch [267/2000], loss_g: 67.5857, loss_d: 0.0000
# Saving generated-images-0267.png
# Epoch [268/2000], loss_g: 70.9160, loss_d: 0.0000
# Saving generated-images-0268.png
# Epoch [269/2000], loss_g: 70.7942, loss_d: 0.0000
# Saving generated-images-0269.png
# Epoch [270/2000], loss_g: 67.5653, loss_d: 0.0000
# Saving generated-images-0270.png
# Epoch [271/2000], loss_g: 70.0598, loss_d: 0.0000
# Saving generated-images-0271.png
# Epoch [272/2000], loss_g: 69.9083, loss_d: 0.0000
# Saving generated-images-0272.png
# Epoch [273/2000], loss_g: 70.9121, loss_d: 0.0000
# Saving generated-images-0273.png
# Epoch [274/2000], loss_g: 71.0601, loss_d: 0.0000
# Saving generated-images-0274.png
# Epoch [275/2000], loss_g: 71.4864, loss_d: 0.0000
# Saving generated-images-0275.png
# Epoch [276/2000], loss_g: 69.9228, loss_d: 0.0000
# Saving generated-images-0276.png
# Epoch [277/2000], loss_g: 67.1353, loss_d: 0.0000
# Saving generated-images-0277.png
# Epoch [278/2000], loss_g: 68.1613, loss_d: 0.0000
# Saving generated-images-0278.png
# Epoch [279/2000], loss_g: 73.8978, loss_d: 0.0000
# Saving generated-images-0279.png
# Epoch [280/2000], loss_g: 69.0457, loss_d: 0.0000
# Saving generated-images-0280.png
# Epoch [281/2000], loss_g: 68.3805, loss_d: 0.0000
# Saving generated-images-0281.png
# Epoch [282/2000], loss_g: 68.7163, loss_d: 0.0000
# Saving generated-images-0282.png
# Epoch [283/2000], loss_g: 68.0616, loss_d: 0.0000
# Saving generated-images-0283.png
# Epoch [284/2000], loss_g: 68.4360, loss_d: 0.0000
# Saving generated-images-0284.png
# Epoch [285/2000], loss_g: 67.9423, loss_d: 0.0000
# Saving generated-images-0285.png
# Epoch [286/2000], loss_g: 69.2400, loss_d: 0.0000
# Saving generated-images-0286.png
# Epoch [287/2000], loss_g: 71.6320, loss_d: 0.0000
# Saving generated-images-0287.png
# Epoch [288/2000], loss_g: 70.4779, loss_d: 0.0000
# Saving generated-images-0288.png
# Epoch [289/2000], loss_g: 68.0250, loss_d: 0.0000
# Saving generated-images-0289.png
# Epoch [290/2000], loss_g: 67.5571, loss_d: 0.0000
# Saving generated-images-0290.png
# Epoch [291/2000], loss_g: 69.3072, loss_d: 0.0000
# Saving generated-images-0291.png
# Epoch [292/2000], loss_g: 65.6036, loss_d: 0.0000
# Saving generated-images-0292.png
# Epoch [293/2000], loss_g: 67.9881, loss_d: 0.0000
# Saving generated-images-0293.png
# Epoch [294/2000], loss_g: 67.4220, loss_d: 0.0000
# Saving generated-images-0294.png
# Epoch [295/2000], loss_g: 66.2103, loss_d: 0.0000
# Saving generated-images-0295.png
# Epoch [296/2000], loss_g: 67.8617, loss_d: 0.0000
# Saving generated-images-0296.png
# Epoch [297/2000], loss_g: 67.7655, loss_d: 0.0000
# Saving generated-images-0297.png
# Epoch [298/2000], loss_g: 66.7508, loss_d: 0.0000
# Saving generated-images-0298.png
# Epoch [299/2000], loss_g: 67.9863, loss_d: 0.0000
# Saving generated-images-0299.png
# Epoch [300/2000], loss_g: 66.6244, loss_d: 0.0000
# Saving generated-images-0300.png
# Epoch [301/2000], loss_g: 66.3709, loss_d: 0.0000
# Saving generated-images-0301.png
# Epoch [302/2000], loss_g: 67.2108, loss_d: 0.0000
# Saving generated-images-0302.png
# Epoch [303/2000], loss_g: 69.7494, loss_d: 0.0000
# Saving generated-images-0303.png
# Epoch [304/2000], loss_g: 67.2162, loss_d: 0.0000
# Saving generated-images-0304.png
# Epoch [305/2000], loss_g: 68.3617, loss_d: 0.0000
# Saving generated-images-0305.png
# Epoch [306/2000], loss_g: 66.0799, loss_d: 0.0000
# Saving generated-images-0306.png
# Epoch [307/2000], loss_g: 68.5449, loss_d: 0.0000
# Saving generated-images-0307.png
# Epoch [308/2000], loss_g: 68.2895, loss_d: 0.0000
# Saving generated-images-0308.png
# Epoch [309/2000], loss_g: 65.7842, loss_d: 0.0000
# Saving generated-images-0309.png
# Epoch [310/2000], loss_g: 68.8088, loss_d: 0.0000
# Saving generated-images-0310.png
# Epoch [311/2000], loss_g: 66.8425, loss_d: 0.0000
# Saving generated-images-0311.png
# Epoch [312/2000], loss_g: 67.0976, loss_d: 0.0000
# Saving generated-images-0312.png
# Epoch [313/2000], loss_g: 67.1706, loss_d: 0.0000
# Saving generated-images-0313.png
# Epoch [314/2000], loss_g: 66.9176, loss_d: 0.0000
# Saving generated-images-0314.png
# Epoch [315/2000], loss_g: 66.7246, loss_d: 0.0000
# Saving generated-images-0315.png
# Epoch [316/2000], loss_g: 65.7791, loss_d: 0.0000
# Saving generated-images-0316.png
# Epoch [317/2000], loss_g: 67.1419, loss_d: 0.0000
# Saving generated-images-0317.png
# Epoch [318/2000], loss_g: 68.8958, loss_d: 0.0000
# Saving generated-images-0318.png
# Epoch [319/2000], loss_g: 66.6436, loss_d: 0.0000
# Saving generated-images-0319.png
# Epoch [320/2000], loss_g: 68.0391, loss_d: 0.0000
# Saving generated-images-0320.png
# Epoch [321/2000], loss_g: 64.6927, loss_d: 0.0000
# Saving generated-images-0321.png
# Epoch [322/2000], loss_g: 66.9574, loss_d: 0.0000
# Saving generated-images-0322.png
# Epoch [323/2000], loss_g: 66.6011, loss_d: 0.0000
# Saving generated-images-0323.png
# Epoch [324/2000], loss_g: 67.7292, loss_d: 0.0000
# Saving generated-images-0324.png
# Epoch [325/2000], loss_g: 65.2367, loss_d: 0.0000
# Saving generated-images-0325.png
# Epoch [326/2000], loss_g: 63.7651, loss_d: 0.0000
# Saving generated-images-0326.png
# Epoch [327/2000], loss_g: 65.8020, loss_d: 0.2118
# Saving generated-images-0327.png
# Epoch [328/2000], loss_g: 36.9981, loss_d: 0.0125
# Saving generated-images-0328.png
# Epoch [329/2000], loss_g: 17.9146, loss_d: 0.1118
# Saving generated-images-0329.png
# Epoch [330/2000], loss_g: 51.9477, loss_d: 0.0101
# Saving generated-images-0330.png
# Epoch [331/2000], loss_g: 40.9455, loss_d: 0.0000
# Saving generated-images-0331.png
# Epoch [332/2000], loss_g: 15.3899, loss_d: 0.7106
# Saving generated-images-0332.png
# Epoch [333/2000], loss_g: 26.8306, loss_d: 0.0940
# Saving generated-images-0333.png
# Epoch [334/2000], loss_g: 73.0212, loss_d: 0.0000
# Saving generated-images-0334.png
# Epoch [335/2000], loss_g: 68.1949, loss_d: 0.0000
# Saving generated-images-0335.png
# Epoch [336/2000], loss_g: 64.2162, loss_d: 0.0000
# Saving generated-images-0336.png
# Epoch [337/2000], loss_g: 27.7815, loss_d: 0.0022
# Saving generated-images-0337.png
# Epoch [338/2000], loss_g: 7.9250, loss_d: 0.0038
# Saving generated-images-0338.png
# Epoch [339/2000], loss_g: 47.9439, loss_d: 0.0000
# Saving generated-images-0339.png
# Epoch [340/2000], loss_g: 40.9249, loss_d: 0.0000
# Saving generated-images-0340.png
# Epoch [341/2000], loss_g: 13.0049, loss_d: 0.0252
# Saving generated-images-0341.png
# Epoch [342/2000], loss_g: 6.7696, loss_d: 0.3113
# Saving generated-images-0342.png
# Epoch [343/2000], loss_g: 17.1649, loss_d: 0.0048
# Saving generated-images-0343.png
# Epoch [344/2000], loss_g: 11.9196, loss_d: 0.0230
# Saving generated-images-0344.png
# Epoch [345/2000], loss_g: 13.0565, loss_d: 0.0451
# Saving generated-images-0345.png
# Epoch [346/2000], loss_g: 15.2402, loss_d: 0.0058
# Saving generated-images-0346.png
# Epoch [347/2000], loss_g: 6.8811, loss_d: 0.0040
# Saving generated-images-0347.png
# Epoch [348/2000], loss_g: 9.6082, loss_d: 0.1008
# Saving generated-images-0348.png
# Epoch [349/2000], loss_g: 13.3063, loss_d: 0.1825
# Saving generated-images-0349.png
# Epoch [350/2000], loss_g: 14.3262, loss_d: 0.0002
# Saving generated-images-0350.png
# Epoch [351/2000], loss_g: 13.2954, loss_d: 0.0082
# Saving generated-images-0351.png
# Epoch [352/2000], loss_g: 10.6396, loss_d: 0.0575
# Saving generated-images-0352.png
# Epoch [353/2000], loss_g: 16.0806, loss_d: 0.2491
# Saving generated-images-0353.png
# Epoch [354/2000], loss_g: 12.3065, loss_d: 0.0792
# Saving generated-images-0354.png
# Epoch [355/2000], loss_g: 15.5278, loss_d: 0.2247
# Saving generated-images-0355.png
# Epoch [356/2000], loss_g: 11.7423, loss_d: 0.0433
# Saving generated-images-0356.png
# Epoch [357/2000], loss_g: 11.5889, loss_d: 0.1815
# Saving generated-images-0357.png
# Epoch [358/2000], loss_g: 21.5564, loss_d: 0.0420
# Saving generated-images-0358.png
# Epoch [359/2000], loss_g: 7.5495, loss_d: 0.1448
# Saving generated-images-0359.png
# Epoch [360/2000], loss_g: 13.6529, loss_d: 0.0196
# Saving generated-images-0360.png
# Epoch [361/2000], loss_g: 13.2310, loss_d: 0.0662
# Saving generated-images-0361.png
# Epoch [362/2000], loss_g: 5.3705, loss_d: 0.0058
# Saving generated-images-0362.png
# Epoch [363/2000], loss_g: 9.1932, loss_d: 0.0419
# Saving generated-images-0363.png
# Epoch [364/2000], loss_g: 12.0350, loss_d: 0.0593
# Saving generated-images-0364.png
# Epoch [365/2000], loss_g: 12.3407, loss_d: 0.0893
# Saving generated-images-0365.png
# Epoch [366/2000], loss_g: 10.7092, loss_d: 0.0394
# Saving generated-images-0366.png
# Epoch [367/2000], loss_g: 15.2464, loss_d: 0.0046
# Saving generated-images-0367.png
# Epoch [368/2000], loss_g: 7.4595, loss_d: 0.0399
# Saving generated-images-0368.png
# Epoch [369/2000], loss_g: 12.4457, loss_d: 0.0109
# Saving generated-images-0369.png
# Epoch [370/2000], loss_g: 8.6673, loss_d: 0.0178
# Saving generated-images-0370.png
# Epoch [371/2000], loss_g: 9.8792, loss_d: 0.0663
# Saving generated-images-0371.png
# Epoch [372/2000], loss_g: 9.2141, loss_d: 0.0207
# Saving generated-images-0372.png
# Epoch [373/2000], loss_g: 12.1865, loss_d: 0.0045
# Saving generated-images-0373.png
# Epoch [374/2000], loss_g: 7.8574, loss_d: 0.0494
# Saving generated-images-0374.png
# Epoch [375/2000], loss_g: 10.5370, loss_d: 0.0088
# Saving generated-images-0375.png
# Epoch [376/2000], loss_g: 21.6040, loss_d: 0.0108
# Saving generated-images-0376.png
# Epoch [377/2000], loss_g: 31.9950, loss_d: 0.0107
# Saving generated-images-0377.png
# Epoch [378/2000], loss_g: 10.8399, loss_d: 0.0030
# Saving generated-images-0378.png
# Epoch [379/2000], loss_g: 47.6100, loss_d: 0.0000
# Saving generated-images-0379.png
# Epoch [380/2000], loss_g: 43.4656, loss_d: 0.0000
# Saving generated-images-0380.png
# Epoch [381/2000], loss_g: 8.9454, loss_d: 0.0127
# Saving generated-images-0381.png
# Epoch [382/2000], loss_g: 9.5675, loss_d: 0.0220
# Saving generated-images-0382.png
# Epoch [383/2000], loss_g: 9.3873, loss_d: 0.0157
# Saving generated-images-0383.png
# Epoch [384/2000], loss_g: 8.5494, loss_d: 0.0024
# Saving generated-images-0384.png
# Epoch [385/2000], loss_g: 7.8828, loss_d: 0.0106
# Saving generated-images-0385.png
# Epoch [386/2000], loss_g: 11.7052, loss_d: 0.0072
# Saving generated-images-0386.png
# Epoch [387/2000], loss_g: 7.1486, loss_d: 0.0059
# Saving generated-images-0387.png
# Epoch [388/2000], loss_g: 9.3830, loss_d: 0.0199
# Saving generated-images-0388.png
# Epoch [389/2000], loss_g: 18.9671, loss_d: 0.0015
# Saving generated-images-0389.png
# Epoch [390/2000], loss_g: 16.8099, loss_d: 0.0036
# Saving generated-images-0390.png
# Epoch [391/2000], loss_g: 55.0505, loss_d: 0.0000
# Saving generated-images-0391.png
# Epoch [392/2000], loss_g: 54.5456, loss_d: 0.0000
# Saving generated-images-0392.png
# Epoch [393/2000], loss_g: 53.9590, loss_d: 0.0000
# Saving generated-images-0393.png
# Epoch [394/2000], loss_g: 55.1477, loss_d: 0.0000
# Saving generated-images-0394.png
# Epoch [395/2000], loss_g: 55.1446, loss_d: 0.0000
# Saving generated-images-0395.png
# Epoch [396/2000], loss_g: 54.8034, loss_d: 0.0000
# Saving generated-images-0396.png
# Epoch [397/2000], loss_g: 54.4991, loss_d: 0.0000
# Saving generated-images-0397.png
# Epoch [398/2000], loss_g: 53.4457, loss_d: 0.0000
# Saving generated-images-0398.png
# Epoch [399/2000], loss_g: 52.8155, loss_d: 0.0000
# Saving generated-images-0399.png
# Epoch [400/2000], loss_g: 55.1030, loss_d: 0.0000
# Saving generated-images-0400.png
# Epoch [401/2000], loss_g: 55.6581, loss_d: 0.0000
# Saving generated-images-0401.png
# Epoch [402/2000], loss_g: 54.1894, loss_d: 0.0000
# Saving generated-images-0402.png
# Epoch [403/2000], loss_g: 54.6503, loss_d: 0.0000
# Saving generated-images-0403.png
# Epoch [404/2000], loss_g: 55.8165, loss_d: 0.0000
# Saving generated-images-0404.png
# Epoch [405/2000], loss_g: 55.6611, loss_d: 0.0000
# Saving generated-images-0405.png
# Epoch [406/2000], loss_g: 54.6709, loss_d: 0.0000
# Saving generated-images-0406.png
# Epoch [407/2000], loss_g: 53.7011, loss_d: 0.0000
# Saving generated-images-0407.png
# Epoch [408/2000], loss_g: 54.9011, loss_d: 0.0000
# Saving generated-images-0408.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# e:\GAN_customV1\gcv1Main.ipynb Cell 18' in <module>
# ----> <a href='vscode-notebook-cell:/e%3A/GAN_customV1/gcv1Main.ipynb#ch0000017?line=0'>1</a> history = trainModel(epochs)
#
# e:\GAN_customV1\gcv1Main.ipynb Cell 16' in trainModel(epochs)
#       <a href='vscode-notebook-cell:/e%3A/GAN_customV1/gcv1Main.ipynb#ch0000015?line=5'>6</a> for epoch in range(epochs):
#       <a href='vscode-notebook-cell:/e%3A/GAN_customV1/gcv1Main.ipynb#ch0000015?line=6'>7</a>     for realImages, _ in  data:
# ----> <a href='vscode-notebook-cell:/e%3A/GAN_customV1/gcv1Main.ipynb#ch0000015?line=8'>9</a>         lossD = trainDISCRIMINATOR(realImages,optimizer_d)
#      <a href='vscode-notebook-cell:/e%3A/GAN_customV1/gcv1Main.ipynb#ch0000015?line=10'>11</a>         lossG = trainGenerator(optimizer_g)
#      <a href='vscode-notebook-cell:/e%3A/GAN_customV1/gcv1Main.ipynb#ch0000015?line=12'>13</a>     generator_Losses.append(lossG)
#
# e:\GAN_customV1\gcv1Main.ipynb Cell 11' in trainDISCRIMINATOR(realImages, optimizer)
#      <a href='vscode-notebook-cell:/e%3A/GAN_customV1/gcv1Main.ipynb#ch0000010?line=25'>26</a> loss.backward()
#      <a href='vscode-notebook-cell:/e%3A/GAN_customV1/gcv1Main.ipynb#ch0000010?line=26'>27</a> optimizer.step()
# ---> <a href='vscode-notebook-cell:/e%3A/GAN_customV1/gcv1Main.ipynb#ch0000010?line=27'>28</a> return loss.item()
#
# KeyboardInterrupt:
